# %%
import pandas as pd

# %%
df = pd.read_csv('dataset2.csv')
df
# Out:
#                      Timestamp How did You hear about Skye8  \
# 0    2025/03/20 9:16:06 am CET               Friends/Family
# 1    2025/03/20 9:21:30 am CET                 Social Media
# 2    2025/03/20 9:25:09 am CET               Friends/Family
# 3    2025/03/20 9:25:57 am CET               Friends/Family
# 4    2025/03/20 9:26:50 am CET               Friends/Family
# 5    2025/03/20 9:27:15 am CET               Friends/Family
# 6    2025/03/20 9:35:10 am CET               Friends/Family
# 7    2025/03/20 9:38:24 am CET               Friends/Family
# 8    2025/03/20 9:38:52 am CET                 Social Media
# 9    2025/03/20 9:40:52 am CET               Friends/Family
# 10   2025/03/20 9:43:19 am CET               Friends/Family
# 11   2025/03/20 9:44:04 am CET                 Social Media
# 12   2025/03/20 9:48:15 am CET               Friends/Family
# 13   2025/03/20 9:54:41 am CET               Friends/Family
# 14   2025/03/20 9:55:43 am CET               Friends/Family
# ...

# %%
df.columns = df.columns.str.strip()

df = df.rename(columns={'How did You hear about Skye8': 'abt_skye8', 
                        'Why did You Choose Skye8?': 'why_skye8',
                        'Is this your first time at skye8?': 'is_first_time_at_skye8',
                        'Department (stack) at Skye8.':'department',
                        'How would you Rate the quality of Learning opportunities provided during the internship? hint: were the projects challenging yet achievable.': 'internship_rating',
                        'Did the internship provide tasks or projects that align with your academic goals.':'did_internship_align_with_your_goals',
                        'Give your reason for the above answer.': 'why',
                        'What skills or knowledge have you gained from the internship, what did you do with them and are they productive?': 'skills_gained',
                        'Were the resources (e.g. tool, equipment, materials) provided sufficient for completing task effectively?':'were_provided_resources_sufficient',
                        'How would you describe the work environment?\n(e.g., Friendly, competitive, stressful, fun, learning-focused, etc.)':'how_would_you_describe_your_working_environment',
                        'How welcoming and inclusive did you find the team? (1-5 scale)\n(1 = Not welcoming, 5 = Very inclusive and supportive)':'how_inclusive_you_fet_into_the_team',
                        'Did you feel valued as an intern?\n(Yes = You felt appreciated; No = You felt like an outsider)':'did_feel_valued_as_intern',
                        'Were you encouraged to share ideas and take initiatives?\n(Yes = Your ideas were welcomed; No = You were expected to just follow orders)': 'was_encouraged_to_share_ideas',
                        'What challenges did you face during your internship?\n(e.g., Lack of guidance, high workload, unclear expectations, poor communication, etc.)': 'challenges_faced',
                        'What could Skye8 do to improve the intern experience?\n(Share suggestions like better onboarding, more structured training, more responsibilities, etc.)': 'how_skye8_cam_improve_intern_satisfaction',
                        'On a scale of 1-10, how satisfied are you with your internship?\n(1 = Very dissatisfied, 10 = Extremely satisfied)': 'how_satified_are_interns',
                        'Would you recommend this internship to others?\n(Yes = You’d tell others to apply; No = You wouldn’t recommend it)':'will_recomend_internship_to_others',
                        'Would you consider working at Skye8 in the future?\n(Yes = You’d love to return; No = You wouldn’t want to work there again)':'would_like_to_work_at_skye8',
                        'Any additional comments or feedback? \n(Open-ended, you can share anything else you feel is important)':'additional_comments',
                        })

# %%
df
# Out:
#                      Timestamp       abt_skye8  \
# 0    2025/03/20 9:16:06 am CET  Friends/Family
# 1    2025/03/20 9:21:30 am CET    Social Media
# 2    2025/03/20 9:25:09 am CET  Friends/Family
# 3    2025/03/20 9:25:57 am CET  Friends/Family
# 4    2025/03/20 9:26:50 am CET  Friends/Family
# 5    2025/03/20 9:27:15 am CET  Friends/Family
# 6    2025/03/20 9:35:10 am CET  Friends/Family
# 7    2025/03/20 9:38:24 am CET  Friends/Family
# 8    2025/03/20 9:38:52 am CET    Social Media
# 9    2025/03/20 9:40:52 am CET  Friends/Family
# 10   2025/03/20 9:43:19 am CET  Friends/Family
# 11   2025/03/20 9:44:04 am CET    Social Media
# 12   2025/03/20 9:48:15 am CET  Friends/Family
# 13   2025/03/20 9:54:41 am CET  Friends/Family
# 14   2025/03/20 9:55:43 am CET  Friends/Family
# 15   2025/03/20 9:56:19 am CET  Friends/Family
# 16   2025/03/20 9:57:30 am CET  Friends/Family
# 17   2025/03/20 9:58:42 am CET  Friends/Family
# 18  2025/03/20 10:10:45 am CET  Friends/Family
# ...
