# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df1 = pd.read_csv('../data/new_File1.csv')
df1
# Out:
#     Age  Gender    School  Start Date    End Date  \
# 0    22    Male     NAHPI  2025-03-01  2025-08-30
# 1    19    Male  COLTECH   2025-02-18  2025-03-22
# 2    21    Male     NAHPI  2025-03-19  2025-09-19
# 3    19    Male   COLTECH  2025-02-18  2025-02-18
# 4    20    Male   COLTECH  2025-02-21  2025-03-22
# 5    20    Male     NAHPI  2025-02-18  2025-08-29
# 6    20    Male   COLTECH  2025-02-12  2025-03-31
# 7    19  Female   COLTECH  2025-02-18  2025-03-31
# 8    22  Female    NAPHI   2025-03-18  2025-05-18
# 9    21  Female     NAHPI  2025-02-18  2025-05-18
# 10   20    Male     NAHPI  2025-03-19  2025-09-19
# 11   20    Male   COLTECH  2025-02-25  2025-03-28
# 12   20  Female    HIPDET  2024-11-19  2025-03-29
# 13   20    Male     NAHPI  2025-03-01  2025-05-01
# 14   20  Female     NAHPI  2025-02-20  2025-09-20
# 15   22  Female    NAHPI   2025-02-19  2025-09-30
# 16   18    Male   COLTECH  2025-02-18  2025-03-22
# 17   25    Male      HICM  2025-02-25  2025-03-29
# 18   19  Female      HICM  2025-11-03  2025-11-09
#
#                                      Internship Goals             School d'pt  \
# 0   Fulfill academic requirements \r\nImprove skil...    COMPUTER ENGINEERING
# 1   1: gain practical experience in network securi...    COMPUTER ENGINEERING
# 2   Gain development skill\r\nnetworking\r\ngain p...    COMPUTER ENGINEERING
# 3   These are some of my goals for the internship ...    COMPUTER ENGINEERING
# 4   1. Learning the basics on html, css and javasc...    COMPUTER ENGINEERING
# 5   - To build my software development skills\r\n-...    COMPUTER ENGINEERING
# 6   -get better at coding \r\n-be so good that I c...    COMPUTER ENGINEERING
# 7                         User did not input anything    COMPUTER ENGINEERING
# 8   To know how to program using python \r\nTo do ...  BIOMEDICAL ENGINEERING
# 9   Learn how to code in Python\r\nAcquire skills ...  BIOMEDICAL ENGINEERING
# 10  Professional growth\r\nSkill development\r\nNe...    COMPUTER ENGINEERING
# 11  - Gain knowledge in data processing with pytho...    COMPUTER ENGINEERING
# 12    To Understand the basic and to build the future    COMPUTER ENGINEERING
# 13  -Learn and apply data manipulation techniques ...    COMPUTER ENGINEERING
# 14  Improve my skills in frontend development \r\n...    COMPUTER ENGINEERING
# 15  Improve skill on  frontend developer\r\nwork o...    COMPUTER ENGINEERING
# 16  - Gain field experience\r\n- Develop skills in...    COMPUTER ENGINEERING
# 17  *To bridge the gap between the theory obtained...       DIGITAL MARKETING
# 18   Aquire skills, gain knowledge and be productive        DIGITAL MARKETING
#
#                  Stack Highest Level of Education Completed
# 0         Data science                       ADVANCED LEVEL
# 1       Cyber security                       ADVANCED LEVEL
# 2             Back-end                       ADVANCED LEVEL
# 3       Cyber security                       ADVANCED LEVEL
# 4            Front-end                       ADVANCED LEVEL
# 5             Back-end                       ADVANCED LEVEL
# 6            Front-end                       ADVANCED LEVEL
# 7            Front-end                       ADVANCED LEVEL
# 8         Data science                       ADVANCED LEVEL
# 9         Data science                       ADVANCED LEVEL
# 10        Data science                       ADVANCED LEVEL
# 11        Data science                       ADVANCED LEVEL
# 12           Front-end                       ADVANCED LEVEL
# 13        Data science                       ADVANCED LEVEL
# 14           Front-end                       ADVANCED LEVEL
# 15           Front-end                       ADVANCED LEVEL
# 16      Cyber security                       ADVANCED LEVEL
# 17  Project management                       ADVANCED LEVEL
# 18   Digital marketing                       ADVANCED LEVEL

# %%
df1['Start Date'] = pd.to_datetime(df1['Start Date'])
df1['End Date'] = pd.to_datetime(df1['End Date'])

# %%
df1['Internship_duration'] = (df1['End Date'] - df1['Start Date']).dt.days
df1
# Out:
#     Age  Gender    School Start Date   End Date  \
# 0    22    Male     NAHPI 2025-03-01 2025-08-30
# 1    19    Male  COLTECH  2025-02-18 2025-03-22
# 2    21    Male     NAHPI 2025-03-19 2025-09-19
# 3    19    Male   COLTECH 2025-02-18 2025-02-18
# 4    20    Male   COLTECH 2025-02-21 2025-03-22
# 5    20    Male     NAHPI 2025-02-18 2025-08-29
# 6    20    Male   COLTECH 2025-02-12 2025-03-31
# 7    19  Female   COLTECH 2025-02-18 2025-03-31
# 8    22  Female    NAPHI  2025-03-18 2025-05-18
# 9    21  Female     NAHPI 2025-02-18 2025-05-18
# 10   20    Male     NAHPI 2025-03-19 2025-09-19
# 11   20    Male   COLTECH 2025-02-25 2025-03-28
# 12   20  Female    HIPDET 2024-11-19 2025-03-29
# 13   20    Male     NAHPI 2025-03-01 2025-05-01
# 14   20  Female     NAHPI 2025-02-20 2025-09-20
# 15   22  Female    NAHPI  2025-02-19 2025-09-30
# 16   18    Male   COLTECH 2025-02-18 2025-03-22
# 17   25    Male      HICM 2025-02-25 2025-03-29
# 18   19  Female      HICM 2025-11-03 2025-11-09
#
#                                      Internship Goals             School d'pt  \
# 0   Fulfill academic requirements \r\nImprove skil...    COMPUTER ENGINEERING
# 1   1: gain practical experience in network securi...    COMPUTER ENGINEERING
# 2   Gain development skill\r\nnetworking\r\ngain p...    COMPUTER ENGINEERING
# 3   These are some of my goals for the internship ...    COMPUTER ENGINEERING
# 4   1. Learning the basics on html, css and javasc...    COMPUTER ENGINEERING
# 5   - To build my software development skills\r\n-...    COMPUTER ENGINEERING
# 6   -get better at coding \r\n-be so good that I c...    COMPUTER ENGINEERING
# 7                         User did not input anything    COMPUTER ENGINEERING
# 8   To know how to program using python \r\nTo do ...  BIOMEDICAL ENGINEERING
# 9   Learn how to code in Python\r\nAcquire skills ...  BIOMEDICAL ENGINEERING
# 10  Professional growth\r\nSkill development\r\nNe...    COMPUTER ENGINEERING
# 11  - Gain knowledge in data processing with pytho...    COMPUTER ENGINEERING
# 12    To Understand the basic and to build the future    COMPUTER ENGINEERING
# 13  -Learn and apply data manipulation techniques ...    COMPUTER ENGINEERING
# 14  Improve my skills in frontend development \r\n...    COMPUTER ENGINEERING
# 15  Improve skill on  frontend developer\r\nwork o...    COMPUTER ENGINEERING
# 16  - Gain field experience\r\n- Develop skills in...    COMPUTER ENGINEERING
# 17  *To bridge the gap between the theory obtained...       DIGITAL MARKETING
# 18   Aquire skills, gain knowledge and be productive        DIGITAL MARKETING
#
#                  Stack Highest Level of Education Completed  \
# 0         Data science                       ADVANCED LEVEL
# 1       Cyber security                       ADVANCED LEVEL
# 2             Back-end                       ADVANCED LEVEL
# 3       Cyber security                       ADVANCED LEVEL
# 4            Front-end                       ADVANCED LEVEL
# 5             Back-end                       ADVANCED LEVEL
# 6            Front-end                       ADVANCED LEVEL
# 7            Front-end                       ADVANCED LEVEL
# 8         Data science                       ADVANCED LEVEL
# 9         Data science                       ADVANCED LEVEL
# 10        Data science                       ADVANCED LEVEL
# 11        Data science                       ADVANCED LEVEL
# 12           Front-end                       ADVANCED LEVEL
# 13        Data science                       ADVANCED LEVEL
# 14           Front-end                       ADVANCED LEVEL
# 15           Front-end                       ADVANCED LEVEL
# 16      Cyber security                       ADVANCED LEVEL
# 17  Project management                       ADVANCED LEVEL
# 18   Digital marketing                       ADVANCED LEVEL
#
#     Internship_duration
# 0                   182
# 1                    32
# 2                   184
# 3                     0
# 4                    29
# 5                   192
# 6                    47
# 7                    41
# 8                    61
# 9                    89
# 10                  184
# 11                   31
# 12                  130
# 13                   61
# 14                  212
# 15                  223
# 16                   32
# 17                   32
# 18                    6

# %%
longest = df1['Internship_duration'].max()
shortest = df1['Internship_duration'].min()

durations = [longest, shortest]
labels = ['longest' , 'shortest']
colors = ['skyblue', 'salmon']

plt.figure(figsize=(8, 7))
plt.bar(labels, durations, color=colors)

plt.title('Longest and shortest internship duration')
plt.xlabel('Duration type')
plt.ylabel('Internship Duration')

for i, value in enumerate(durations):
    plt.text(i, value + 5, str(value), ha='center')

#mean internship duration
avg_duration = df1['Internship_duration'].mean()
plt.axhline(avg_duration, color = 'red', linestyle = '--', label = 'Average duration')
plt.legend()

plt.show()

# %%
#box plot to visualize duration of internship

plt.figure(figsize=(10, 5))
sns.boxplot(x=df1['Internship_duration'], color='salmon')
plt.title('Intern Duration (Days)')
plt.xlabel('Days')
plt.show()

# %%
Q1 = df1['Internship_duration'].quantile(0.25)
Q3 = df1['Internship_duration'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR 

outliers = df1[(df1['Internship_duration'] < lower_bound) | (df1['Internship_duration'] > upper_bound)]

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df1.index, y=df1['Internship_duration'], color = 'blue', label = 'Normal Data')
plt.axhline(lower_bound, color = 'red', linestyle = '--', label = 'Lower Bound')
plt.axhline(upper_bound, color = 'red', linestyle = '--', label = 'Upper Bound')
plt.title('IQR-Based Outlier Detection')
plt.xlabel('Index')
plt.ylabel('Duration (days)')
plt.legend()
plt.show()
