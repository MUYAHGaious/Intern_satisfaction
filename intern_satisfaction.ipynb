# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('dataset1.csv')
df1
# Out:
#                      Timestamp                     Username  \
# 0    2025/03/20 6:29:54 am CET        billleynyuy@gmail.com
# 1    2025/03/20 9:19:58 am CET     tokohbelmond55@gmail.com
# 2    2025/03/20 9:20:31 am CET    awankembenjamin@gmail.com
# 3    2025/03/20 9:21:52 am CET  wordswothlemuel61@gmail.com
# 4    2025/03/20 9:25:30 am CET          liforlavj@gmail.com
# 5    2025/03/20 9:31:01 am CET    chenebametuge14@gmail.com
# 6    2025/03/20 9:31:24 am CET       joneswainfen@gmail.com
# 7    2025/03/20 9:31:49 am CET         bcleratine@gmail.com
# 8    2025/03/20 9:33:03 am CET      mambolentine7@gmail.com
# 9    2025/03/20 9:33:15 am CET    techaprideakana@gmail.com
# 10   2025/03/20 9:33:40 am CET        mafowillson@gmail.com
# 11   2025/03/20 9:40:24 am CET     muforbelmond20@gmail.com
# 12   2025/03/20 9:42:34 am CET         peggylafen@gmail.com
# 13   2025/03/20 9:45:51 am CET      muyahgaious97@gmail.com
# 14   2025/03/20 9:47:37 am CET      delineswift54@gmail.com
# ...

# %%
df2 = pd.read_csv('dataSet2.csv')
df2.head()
# Out:
#                    Timestamp How did You hear about Skye8  \
# 0  2025/03/20 9:16:06 am CET               Friends/Family
# 1  2025/03/20 9:21:30 am CET                 Social Media
# 2  2025/03/20 9:25:09 am CET               Friends/Family
# 3  2025/03/20 9:25:57 am CET               Friends/Family
# 4  2025/03/20 9:26:50 am CET               Friends/Family
#
#                           Why did You Choose Skye8?   \
# 0  I actually did internship in year1 at skye8 so...
# 1  Because I heard of their innovative dreams of ...
# 2  because they separate interns into different s...
# 3  Mainly because it's closest to my home and als...
# 4               Because it was the best choice I had
#
#   Is this your first time at skye8? Department (stack) at Skye8.  \
# 0                                No                     Back-end
# 1                               Yes                    Front-end
# 2                                No                    Front-end
# ...

# %%
df2.describe()
# Out:
#        How would you rate the support provided by your supervisor? (1-5 scale)\n(1 = No support at all, 5 = Very helpful and supportive)  \
# count                                          21.000000
# mean                                            3.809524
# std                                             0.872872
# min                                             3.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        How welcoming and inclusive did you find the team? (1-5 scale)\n(1 = Not welcoming, 5 = Very inclusive and supportive)  \
# count                                          21.000000
# mean                                            4.142857
# std                                             0.792825
# min                                             3.000000
# ...

# %%
df3 = pd.read_csv('gas_prices.csv')
df3.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.87    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
df3.isnull().sum()
# Out:
# Year           0
# Australia      1
# Canada         0
# France         0
# Germany        0
# Italy          0
# Japan          0
# Mexico         0
# South Korea    0
# UK             0
# USA            0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Timestamp                                                                                                                                                   0
# How did You hear about Skye8                                                                                                                                0
# Why did You Choose Skye8?                                                                                                                                   0
# Is this your first time at skye8?                                                                                                                           0
# Department (stack) at Skye8.                                                                                                                                0
# How would you Rate the quality of Learning opportunities provided during the internship? hint: were the projects challenging yet achievable.                0
# ...
